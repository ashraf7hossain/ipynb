# %%
from numpy import * 
from pandas import * 
from matplotlib import pyplot as plt 
from sklearn.linear_model import LinearRegression 

dt = read_csv("https://raw.githubusercontent.com/ashraf7hossain/ipynb/main/data.csv")

x = DataFrame(dt['height'])
y = DataFrame(dt['weight'])

plt.scatter(x , y, color = "red")

model = LinearRegression().fit(x , y)

plt.plot(x , model.predict(x), color = "green")

# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/ashraf7hossain/ipynb/main/data.csv")

# data.head()

data['height']
# Out:
# 0      65.78
# 1      71.52
# 2      69.40
# 3      68.22
# 4      67.79
#        ...
# 195    65.80
# 196    66.11
# 197    68.24
# 198    68.02
# 199    71.39
# Name: height, Length: 200, dtype: float64
